# %% [markdown]
# # HBase NoSQL
#
# Create a wide-column table and perform low-latency reads.
#
# ![Architecture](../assets/aws_data_engineering_architecture.svg)

# %%
from pathlib import Path
import os, sys, json, subprocess
ROOT=Path('..').resolve()
DRY_RUN=os.getenv('DRY_RUN','true').lower()!='false'
print({'root':str(ROOT),'dry_run':DRY_RUN})

# %% [markdown]
# Inspect HBase shell commands.

# %%
print((ROOT/'jobs/hbase/customer_events.hbase').read_text())

# %% [markdown]
# HBase shell command.

# %%
print('hbase shell jobs/hbase/customer_events.hbase')
